# %% [markdown]
# ## importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import tarfile
# import urllib.request

# %%
df = pd.read_csv("exampleData1.csv", encoding="latin1")
df.head()
# Out:
#     name   q1   q2   q3   q4   q5   q6   q7   q8   q9  ...  \
# 0  anon1  5.0  3.0  5.0  3.0  0.0  3.0  3.0  4.0  4.0  ...
# 1  anon2  5.0  2.0  3.0  0.0  3.0  3.0  4.0  4.0  2.0  ...
# 2  anon3  2.0  5.0  1.0  0.0  0.0  3.0  4.0  1.0  1.0  ...
# 3  anon4  2.0  3.0  0.0  4.0  0.0  4.0  0.0  0.0  2.0  ...
# 4  anon5  2.0  2.0  0.0  4.0  5.0  2.0  1.0  0.0  2.0  ...
#
#                                                  q21  \
# 0  The professor barely covers the material, leav...
# 1  Students dread attending the professor's lectu...
# 2  The professor rarely provides feedback on assi...
# 3  Ö?renciler, profesörün tav?rlar?ndan çekinirle...
# 4  Profesörün ö?retim tarz? eski moda ve modern ö...
#
#                                                  q22  \
# 0  The course lacks structure, with the professor...
# 1  The professor is frequently late to class and ...
# 2  Students struggle to understand the professor'...
# 3  Profesör, ö?rencilerin çe?itli ö?renme ihtiyaç...
# 4  Profesör, s?k s?k son dakikada dersi iptal ede...
#
#                                                  q23  \
# 0  The professor shows little enthusiasm for the ...
# 1  Course materials are outdated, and the profess...
# 2  The professor assigns excessive homework, leav...
# 3  Profesörün dersleri net hedeflerden yoksun, bu...
# 4  Ö?renciler, profesörün ders d???nda eri?ilebil...
#
#                                                  q24  \
# 0  The professor's grading criteria are unclear, ...
# 1  The professor frequently goes off on tangents ...
# 2  Despite students' questions, the professor dis...
# 3  Ders ödevleri yarat?c? de?il ve ö?rencileri en...
# 4  Profesörün ö?retim yöntemleri farkl? ö?renme t...
#
#                                                  q25  \
# 0  The professor's teaching methods are ineffecti...
# 1  Students find it challenging to reach the prof...
# 2  The professor fails to create an inclusive lea...
# 3  Profesör, ö?rencilerin sorular?yla ilgilenmez ...
# 4  Profesörün dersleri gerçek dünya örneklerinden...
#
#                                                  q26  \
# 0  Course lectures are disorganized, making it di...
# 1  The professor lacks empathy towards students' ...
# 2  The professor's slides are cluttered and diffi...
# 3  Profesör, i?birli?ine dayal? bir ö?renme ortam...
# 4  Ders materyalleri eski ve güncel geli?meleri y...
#
#                                                  q27  \
# 0  The professor's explanations are overly comple...
# 1  Students feel unsupported by the professor, es...
# 2  The professor assigns group projects without p...
# 3  Profesörün konuya olan ilgisizli?i ö?renci mot...
# 4  Profesörün ö?retim tarz? ö?rencilerin dikkatin...
#
#                                                  q28  \
# 0  The professor's quizzes and exams are excessiv...
# 1  The professor favors certain students, creatin...
# 2  Students find it difficult to engage with the ...
# 3  Profesörün ders d???nda eri?ilebilir olmamas?,...
# 4  Ö?renciler, profesörün konuya olan tutkusundan...
#
#                                                  q29  \
# 0  The professor frequently cancels office hours,...
# 1  The professor's assignments are irrelevant to ...
# 2  The professor lacks enthusiasm for the subject...
# 3  Profesör, ö?rencilerin farkl? ö?renme stilleri...
# 4  Ders materyalleri, konuyu anlamay? zorla?t?rac...
#
#                                                  q30
# 0  Course readings are dense and uninteresting, d...
# 1  The professor fails to address students' misco...
# 2  The professor rarely incorporates multimedia o...
# 3  Ö?renciler, profesörün derslerinin dikkatsizli...
# 4  Profesör, ö?rencilere gereken özeni göstermez ...
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   q1      7 non-null      float64
#  2   q2      7 non-null      float64
#  3   q3      7 non-null      float64
#  4   q4      7 non-null      float64
#  5   q5      7 non-null      float64
#  6   q6      7 non-null      float64
#  7   q7      7 non-null      float64
#  8   q8      7 non-null      float64
#  9   q9      7 non-null      float64
#  10  q10     7 non-null      float64
#  11  q11     7 non-null      float64
#  12  q12     7 non-null      float64
#  13  q13     7 non-null      float64
#  14  q14     7 non-null      float64
#  15  q15     7 non-null      float64
#  16  q16     7 non-null      float64
#  17  q17     7 non-null      float64
#  18  q18     7 non-null      float64
#  19  q19     7 non-null      float64
#  20  q20     7 non-null      float64
#  21  q21     7 non-null      object
#  22  q22     7 non-null      object
#  23  q23     8 non-null      object
#  24  q24     7 non-null      object
#  25  q25     7 non-null      object
#  26  q26     7 non-null      object
#  27  q27     7 non-null      object
#  28  q28     7 non-null      object
#  29  q29     7 non-null      object
#  30  q30     7 non-null      object
# dtypes: float64(20), object(11)
# memory usage: 11.8+ KB

# %%
df.describe()
# Out:
#              q1        q2        q3        q4        q5        q6        q7  \
# count  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
# mean   3.571429  2.428571  2.142857  2.285714  1.142857  3.285714  2.571429
# std    1.511858  1.511858  2.193063  1.889822  2.035401  0.951190  1.618347
# min    2.000000  0.000000  0.000000  0.000000  0.000000  2.000000  0.000000
# 25%    2.000000  2.000000  0.500000  0.500000  0.000000  3.000000  1.500000
# 50%    4.000000  2.000000  1.000000  3.000000  0.000000  3.000000  3.000000
# 75%    5.000000  3.000000  4.000000  4.000000  1.500000  3.500000  4.000000
# max    5.000000  5.000000  5.000000  4.000000  5.000000  5.000000  4.000000
#
#              q8        q9       q10       q11       q12       q13       q14  \
# count  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
# mean   1.714286  2.285714  3.428571  2.000000  2.714286  3.571429  2.428571
# std    1.889822  0.951190  1.511858  1.825742  1.704336  1.397276  1.511858
# min    0.000000  1.000000  1.000000  0.000000  1.000000  2.000000  0.000000
# 25%    0.000000  2.000000  2.500000  1.000000  1.500000  2.500000  2.000000
# 50%    1.000000  2.000000  4.000000  1.000000  2.000000  3.000000  2.000000
# 75%    3.500000  2.500000  4.500000  3.000000  4.000000  5.000000  3.000000
# max    4.000000  4.000000  5.000000  5.000000  5.000000  5.000000  5.000000
#
#             q15       q16       q17       q18       q19       q20
# count  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
# mean   2.714286  2.142857  3.285714  3.142857  2.142857  1.857143
# std    1.976047  1.214986  1.976047  1.573592  1.864454  1.069045
# min    0.000000  0.000000  0.000000  1.000000  0.000000  1.000000
# 25%    1.500000  2.000000  2.500000  2.000000  1.000000  1.000000
# 50%    3.000000  2.000000  4.000000  3.000000  1.000000  2.000000
# 75%    4.000000  2.500000  4.500000  4.500000  3.500000  2.000000
# max    5.000000  4.000000  5.000000  5.000000  5.000000  4.000000

# %%
df.hist(bins=50, figsize=(12,8))
plt.show()

# %%
train_set, test_set = shuffle_and_split_data(df, 0.2)
print(len(test_set))
# Out:
# 48

# %%
def shuffle_and_split_data(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data))
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return df.iloc[train_indices], df.iloc[test_indices]

# %%
train_set, test_set = shuffle_and_split_data(df, 0.2)
print(len(test_set))
# Out:
# 48
