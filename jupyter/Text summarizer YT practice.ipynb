# %% [markdown]
# # importing libraries

# %%
import nltk
nltk.data.path.append(r'C:\Users\tivadigi\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk')

import string
from heapq import nlargest

# %%
print("i can do anything and everything is going to be alright")
# Out:
# i can do anything and everything is going to be alright

# %% [markdown]
# # prepare and read the text data

# %%
with open("ML.txt", "r", encoding="utf8") as f: text=f.read()

# %%
print(text)
# Out:
# Definition
# What is machine learning and how does it work? In-depth guide
#
# By
#
#     Linda Tucci, Industry Editor -- CIO/IT Strategy
#     Ed Burns
#
# Machine learning (ML) is a type of artificial intelligence (AI) focused on building computer systems that learn from data. The broad range of techniques ML encompasses enables software applications to improve their performance over time.
#
# Machine learning algorithms are trained to find relationships and patterns in data. They use historical data as input to make predictions, classify information, cluster data points, reduce dimensionality and even help generate new content, as demonstrated by new ML-fueled applications such as ChatGPT, Dall-E 2 and GitHub Copilot.
#
# ...

# %% [markdown]
# # generating the word cloud image

# %%
import matplotlib.pyplot as plt
from wordcloud import  WordCloud, STOPWORDS

# print(STOPWORDS)
# print("there are ", format(len(text)),  "words in the entire text")
# !pip install wordcloud

WC = WordCloud(stopwords=STOPWORDS, background_color="white").generate(text)

plt.figure(figsize=(15,19))
plt.imshow(WC, interpolation='bilinear')
plt.show()

# %% [markdown]
# # Keyword extraction

# %%
# import nltk
# nltk.download('stopwords')
# C:\Users\tivadigi\AppData\Roaming\nltk_data\corpora\
# C:\Users\tivadigi\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk
from rake_nltk import Rake
# nltk.data.path.append(r'C:\Users\tivadigi\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk')

rk = Rake()

rk.extract_keywords_from_text(text)
extract_keyword = rk.get_ranked_phrases_with_scores()
print(extract_keyword)

# !pip install rake-nltk
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[6], line 10
#       6 # nltk.data.path.append(r'C:\Users\tivadigi\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk')
#       8 rk = Rake()
# ---> 10 rk.extract_keywords_from_text(text)
#      11 extract_keyword = rk.get_ranked_phrases_with_scores()
#      12 print(extract_keyword)
#
# File ~\anaconda3\Lib\site-packages\rake_nltk\rake.py:126, in Rake.extract_keywords_from_text(self, text)
#     121 def extract_keywords_from_text(self, text: str):
#     122     """Method to extract keywords from the text provided.
#     123
#     124     :param text: Text to extract keywords from, provided as a string.
#     125     """
# --> 126     sentences: List[Sentence] = self._tokenize_text_to_sentences(text)
#     127     self.extract_keywords_from_sentences(sentences)
#
# ...
